# %% [markdown]
# <a href="https://colab.research.google.com/github/programmingconsole/Python_Data_Analytics/blob/main/mathplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip --version
# Out:
# pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()             # Create a figure containing a single Axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the Axes.
plt.show()                           # Show the figure.

# %%
x=np.arange(0,5,0.1)
z=np.arange(0,5,0.2)
y=np.sin(x)

plt.plot(x,y,z)

plt.show()

# %%
m=['Data analyst','software','cd','bca','df']
s=[2,3,1,4,5]

plt.plot(m,s)

plt.title("See the analythic")

plt.ylabel('its a ratios')
# Out:
# Text(0, 0.5, 'its a ratios')

# %%
plt.bar(m,s)
# Out:
# <BarContainer object of 5 artists>
